# %% [markdown]
# ### HW : Do 20 different slicing operations of your own name.

# %%
name = 'Rutuja Darveshi' 

print(name[0:15])

print(name[-1:-16:-1])

print(name[-15:-7])

print(name[0:6])

print(name[7:15])

print(name[0:4])

print(name[-14:-11:+2])

print(name[1:15:+2])

print(name[ :-3:+7])

print(name[:3:],name[10:12])

print(name[-8:-5], name[4:6])

print(name[: 7+8: +5])

print(name[-15:-13])

print(name[-15:-11])

print(name[ : : +1])

print(name[ -8: : -1])

print(name[-8:len(name)])

print(name[-11:-6])

print(name[3+3:10])

print(name[-9:len(name):+2])

print(name[1+1+1:-3-3])

print(name[2:-11], name[3-1:4])

print(name[0+7:6+6+2])

print(name[-10:-2:+3])

print(name[13:-16:-4])
# Out:
# Rutuja Darveshi
# ihsevraD ajutuR
# Rutuja D
# Rutuja
# Darveshi
# Rutu
# uu
# uuaDreh
# RD
# Rut ve
# Dar ja
# Rav
# Ru
# Rutu
# Rutuja Darveshi
# D ajutuR
# Darveshi
# ja Da
#  Dar
#  avsi
# uja Da
# tu tu
# Darvesh
# aae
# hrau
