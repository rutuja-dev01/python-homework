# %%
price = 99.50

print(price)
print(type(price))
print(id(price))
# Out:
# 99.5
# <class 'float'>
# 1811046572976

# %%
city = 'Pune'

print(city)
print(type(city))
print(id(city))
# Out:
# Pune
# <class 'str'>
# 1811046712400

# %%
marks = 85

print(marks)
print(type(marks))
print(id(marks))
# Out:
# 85
# <class 'int'>
# 140720746786552
