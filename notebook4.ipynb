# %%
result = False

print(result)
print(type(result))
print(id(result))
# Out:
# False
# <class 'bool'>
# 140720745884448

# %%
temperature = 36.6

print(temperature)
print(type(temperature))
print(id(temperature))
# Out:
# 36.6
# <class 'float'>
# 2246767840880

# %%
value = 0

print(value)
print(type(value))
print(id(value))
# Out:
# 0
# <class 'int'>
# 140720746783832
