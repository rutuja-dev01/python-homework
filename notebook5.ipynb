# %%
year = 2026

print(year)
print(type(year))
print(id(year))
# Out:
# 2026
# <class 'int'>
# 1874784691504

# %%
course = "BCA"

print(course)
print(type(course))
print(id(course))
# Out:
# BCA
# <class 'str'>
# 1874786014704

# %%
subject = "DBMS"

print(subject)
print(type(subject))
print(id(subject))
# Out:
# DBMS
# <class 'str'>
# 1874786015376
