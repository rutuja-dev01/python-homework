# %%
age = 20

print(age)
print(type(age))
print(id(age))
# Out:
# 20
# <class 'int'>
# 140720746784472

# %%
language = "Python"

print(language)
print(type(language))
print(id(language))
# Out:
# Python
# <class 'str'>
# 2238929764192

# %%
number = -25

print(number)
print(type(number))
print(id(number))
# Out:
# -25
# <class 'int'>
# 2239016462160
