# %%
number = 1111

print(number)
print(type(number))
print(id(number))
# Out:
# 1111
# <class 'int'>
# 2365543541744

# %%
name = 'Rutuja'

print(name)
print(type(name))
print(id(name))
# Out:
# Rutuja
# <class 'str'>
# 2365545602464

# %%
is_student = True

print(is_student)
print(type(is_student))
print(id(is_student))
# Out:
# True
# <class 'bool'>
# 140720745884416
